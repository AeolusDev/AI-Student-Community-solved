# %% [markdown]
# # COTW 38 Notebook

# %% [markdown]
# ## 1. Write a function to find whether a number is prime or not.

# %%
# Your code here

# %% [markdown]
# ## 2. Write a function to determine whether the given text is an email or not. (Hint: Use regex library)

# %%
# Your code here

# %% [markdown]
# ## 3. Write a function to tell whether the given number is a square, a cube or a none of them. (Hint: Use math library)

# %%
# Your code here

# %% [markdown]
# ## 4. Write a function to convert a text file into pdf. (Hint:

# %%
# Your code here

# %% [markdown]
# ## 5. Write a code which wishes you "HAPPY BIRTHDAY" when the date is your birthdate.

# %%
# Your code here

# %% [markdown]
# ## 6. Write a code which creates an inner function to calculate the addition in the following way:
#
# a. Create an outer function that will accept two parameters, a and b that will square the value of a and return it
#
# b. Create an inner function inside an outer function that will calculate the addition of a and b
#
# c. At last, an outer function will add 5 into addition and return it
#
# d. Print the values of both outer and inner functions

# %%
# Your code here

# %% [markdown]
# ## 7. Write a program to create a function show_employee() using the following conditions:
#
# It should accept the employee’s name and salary and display both
#
# If the salary is missing in the function call then assign default value 9000 to salary
#
# Call the function with the salary value and without the salary value and print the result

# %%
# Your code here

# %% [markdown]
# ## 8. Write a program which will take a string as input and returns the entire string in reverse

# %%
# Your code here

# %% [markdown]
# ## 9. Write a program that asks the user how many Fibonacci numbers to generate and then generates them

# %%
# Your code here

# %% [markdown]
# # Write a program that will play the game Yayy and Nayy with the user
#
# The game works like this:
#
# **Step 1:** Randomly generate a 4-digit number
#
# **Step 2:** Ask the user to guess a 4-digit number
#
# **Step 3:** For every digit that the user guessed correctly in the correct place, they have a “yayy”. For every digit the user guessed correctly in the wrong place is a “nayy.” Every time the user makes a guess, tell them how many “yayy” and “nayy” they have. Once the user guesses the correct number, the game is over. Keep track of the number of guesses the user makes throughout the game and tell the user at the end.
#
# Say the number generated by the computer is 1038. The game works like this:
#
# Welcome to the Yayy and Nayy game!
#
# Enter a number:
# ### >>> 1234
#
# **You have 2 Yayy and 0 Nayy**
#
# Enter a number:
# ### >>> 1256
#
# **You have 1 Yayy and 1 Nayy**
#
# **Step 4:** The game continues until the user guesses the number.

# %%
# Your code here

# %% [markdown]
# # Create a password generator in Python
#
# ## 1. Generate an 8-character password with length "passlen" with no duplicate characters in the password
#
# ## 2. Generate a random password that would ask the user "how many characters in your password?" and return the password with those many characters

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# # Hope you had fun participating in the challenge!
